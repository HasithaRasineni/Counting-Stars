# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
#Reading the imgae in gray scale
img = imread('C:/Users/Hasitha Rasineni/Desktop/stars.png',as_grey = 'True', plugin='matplotlib')
print(img.shape)

# %%
#Displaying the image
plt.imshow(im, cmap=cm.gray)
plt.show()

# %%
from math import sqrt
from skimage.feature import blob_dog, blob_log, blob_doh

#Counting the #Stars using blobs_log method (Pretty Accurate)
blobs_log = blob_log(img, max_sigma = 30, num_sigma = 10, threshold = .1)
# Computing radii in the 3rd column
blobs_log[:, 2] = blobs_log[:, 2] * sqrt(2)
num = len(blobs_log)
print('Number of Stars Counted using blob_log = ', num)

#Counting the #Stars using blob_dog method
blobs_dog = blob_dog(img, max_sigma =30, threshold = .09)
blobs_dog[:, 2] = blobs_dog[:, 2] * sqrt(2)
num = len(blobs_dog)
print('Number of Stars Counted using blob_dog = ', num)

#Counting the #Stars using blob_doh method 
blobs_doh = blob_doh(img, max_sigma = 30, threshold = .001)
blobs_doh[:, 2] = blobs_doh[:, 2] * sqrt(2)
num = len(blobs_doh)
print('Number of Stars Counted using blobs_doh = ', num)
# Out:
# Number of Stars Counted using blob_log =  490
# Number of Stars Counted using blob_dog =  160
# Number of Stars Counted using blobs_doh =  607

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(img, cmap = plt.cm.gray)
for i in blobs_log:
    y, x, r = i
    c = plt.Circle((x, y), r+5, color = 'y', linewidth = 2, fill = False)
    ax.add_patch(c)

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(img, cmap = plt.cm.gray)
for i in blobs_dog:
    y, x, r = i
    c = plt.Circle((x, y), r+5, color = 'y', linewidth = 2, fill = False)
    ax.add_patch(c)

# %%
fig, ax = plt.subplots(1, 1)
plt.imshow(img, cmap = plt.cm.gray)
for i in blobs_doh:
    y, x, r = i
    c = plt.Circle((x, y), r+5, color= 'y', linewidth = 2, fill = False)
    ax.add_patch(c)
